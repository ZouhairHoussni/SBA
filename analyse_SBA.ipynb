# %%
import pandas as pd

df = pd.read_csv("SBA.csv")

df.sort_values(by='Name')
# Out:
# /tmp/ipykernel_52777/2451253889.py:3: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("SBA.csv")
#         LoanNr_ChkDgt  ...      SBA_Appv
# 554017     5439964000  ...   $42,500.00
# 569861     5617804002  ...   $73,950.00
# 279704     2939984009  ...  $187,500.00
# 360049     3510403005  ...   $72,000.00
# 16190      1117714005  ...   $40,000.00
# ...               ...  ...           ...
# 197428     2392384001  ...   $22,400.00
# 198019     2396634001  ...   $24,000.00
# 280514     2944725002  ...   $75,000.00
# 507780     4915765003  ...   $22,500.00
# 556232     5466095001  ...  $110,000.00
#
# [899164 rows x 27 columns]

# %%
df[df['GrAppv'] == df['DisbursementGross']]
# Out:
#         LoanNr_ChkDgt  ...      SBA_Appv
# 0          1000014003  ...   $48,000.00
# 1          1000024006  ...   $32,000.00
# 2          1000034009  ...  $215,250.00
# 3          1000044001  ...   $28,000.00
# 4          1000054004  ...  $229,000.00
# ...               ...  ...           ...
# 899159     9995573004  ...   $56,000.00
# 899160     9995603000  ...   $42,500.00
# 899161     9995613003  ...  $225,000.00
# 899162     9995973006  ...   $60,000.00
# 899163     9996003010  ...   $24,000.00
#
# [688683 rows x 27 columns]

# %%
df.sort_values(by="Bank")
# Out:
#         LoanNr_ChkDgt  ...      SBA_Appv
# 384352     3704384006  ...   $14,000.00
# 724701     7541164002  ...  $187,500.00
# 861321     9269234009  ...   $10,000.00
# 375661     3634784001  ...   $84,000.00
# 845614     9067203006  ...   $68,000.00
# ...               ...  ...           ...
# 888537     9772941008  ...  $350,000.00
# 888681     9775961009  ...   $49,500.00
# 897114     9950351001  ...   $48,750.00
# 897474     9958533004  ...   $20,000.00
# 897749     9964143001  ...  $382,050.00
#
# [899164 rows x 27 columns]

# %%
df.describe()
# Out:
#        LoanNr_ChkDgt            Zip  ...  FranchiseCode     UrbanRural
# count   8.991640e+05  899164.000000  ...  899164.000000  899164.000000
# mean    4.772612e+09   53804.391241  ...    2753.725933       0.757748
# std     2.538175e+09   31184.159152  ...   12758.019136       0.646436
# min     1.000014e+09       0.000000  ...       0.000000       0.000000
# 25%     2.589758e+09   27587.000000  ...       1.000000       0.000000
# 50%     4.361439e+09   55410.000000  ...       1.000000       1.000000
# 75%     6.904627e+09   83704.000000  ...       1.000000       1.000000
# max     9.996003e+09   99999.000000  ...   99999.000000       2.000000
#
# [8 rows x 10 columns]

# %%
df['ApprovalFY'] = pd.to_numeric(df['ApprovalFY'], errors='coerce')

# %%
 # import sweetviz as sv

# report = sv.analyze(df)

# report.show_html()

# %%
#df[df['']==1].shape[0]

#filtered_df = df.loc[(df['FranchiseCode'] != 1) & (df['FranchiseCode'] != 0)]

# get the number of rows in the filtered DataFrame
#count = filtered_df.shape[0]

# %%
missing_values = df.isna().sum()
print(missing_values)
# Out:
# LoanNr_ChkDgt             0
# Name                     14
# City                     30
# State                    14
# Zip                       0
# Bank                   1559
# BankState              1566
# NAICS                     0
# ApprovalDate              0
# ApprovalFY               18
# Term                      0
# NoEmp                     0
# NewExist                136
# CreateJob                 0
# RetainedJob               0
# FranchiseCode             0
# UrbanRural                0
# RevLineCr              4528
# LowDoc                 2582
# ChgOffDate           736465
# DisbursementDate       2368
# DisbursementGross         0
# BalanceGross              0
# MIS_Status             1997
# ChgOffPrinGr              0
# GrAppv                    0
# SBA_Appv                  0
# dtype: int64

# %%
key_column = 'Zip'
value_column = 'City'

# Create the dictionary
Zip_dict = df.set_index(key_column)[value_column].to_dict()

Zip_dict = {str(key): value for key, value in Zip_dict.items()}

Zip_dict
# Out:
# {'47711': 'EVANSVILLE',
#  '46526': 'GOSHEN',
#  '47401': 'BLOOMINGTON',
#  '74012': 'BROKEN ARROW',
#  '32801': 'ORLANDO',
#  '6062': 'PLAINVILLE',
#  '7083': 'UNION',
#  '34491': 'SUMMERFIELD',
#  '32456': 'PORT ST JOE',
#  '6073': 'SOUTH GLASTONBURY',
#  '28256': 'CHARLOTTE',
#  '60605': 'CHICAGO',
#  '27502': 'APEX',
#  '2876': 'SLATERSVILLE',
#  '27106': 'WINSTON-SALEM',
#  '73112': 'OKLAHOMA CITY',
#  '79701': 'MIDLAND',
#  '20120': 'CENTREVILLE',
#  '75093': 'PLANO',
#  '37922': 'KNOXVILLE',
#  '79029': 'DUMAS',
#  '33065': 'CORAL SPRINGS',
#  '2919': 'JOHNSTON',
#  '76040': 'EULESS',
#  '72223': 'LITTLE ROCK',
#  '56082': 'ST. PETER',
#  '64055': 'KANSAS CITY',
#  '2050': 'MARSHFIELD (CENSUS NAME FOR MA',
#  '93010': 'CAMARILLO',
#  '29621': 'ANDERSON',
#  '33186': 'MIAMI',
#  '75243': 'DALLAS',
#  '70130': 'NEW ORLEANS',
#  '52353': 'WASHINGTON',
#  '78641': 'LEANDER',
#  '24015': 'ROANOKE',
#  '44428': 'KINSMAN',
#  '2356': 'MARSHFIELD',
#  '37172': 'SPRINGFIELD',
# ...

# %%
key_column = 'City'
value_column = 'State'

# Create the dictionary
city_dict = df.set_index(key_column)[value_column].to_dict()

# %%
df['State'] = df.apply(lambda x: city_dict[x['City']] if pd.isna(x['State']) else x['State'], axis=1)

# %%
df['City'] = df.apply(lambda x: city_dict[x['Zip']] if pd.isna(x['City']) else x['City'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [72], line 1
# ----> 1 df['City'] = df.apply(lambda x: city_dict[x['Zip']] if pd.isna(x['City']) else x['City'], axis=1)
#
# File ~/miniconda3/envs/new_env/lib/python3.10/site-packages/pandas/core/frame.py:9555, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9544 from pandas.core.apply import frame_apply
#    9546 op = frame_apply(
#    9547     self,
#    9548     func=func,
#    (...)
#    9553     kwargs=kwargs,
#    9554 )
# -> 9555 return op.apply().__finalize__(self, method="apply")
#
# File ~/miniconda3/envs/new_env/lib/python3.10/site-packages/pandas/core/apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# ...

# %%
df[df['City'].isna()]
# Out:
#         LoanNr_ChkDgt  ...      SBA_Appv
# 42535      1330603010  ...  $190,000.00
# 177891     2268732010  ...  $500,000.00
# 243450     2716822007  ...  $150,000.00
# 243452     2716832010  ...   $49,000.00
# 270263     2884182004  ...  $488,000.00
# 270265     2884192007  ...  $211,000.00
# 270268     2884202008  ...  $407,000.00
# 270270     2884212000  ...  $105,000.00
# 270277     2884232006  ...  $159,000.00
# 270284     2884252001  ...  $365,000.00
# 326169     3258222000  ...  $205,000.00
# 342177     3386722002  ...   $25,000.00
# 342185     3386762003  ...   $71,000.00
# 342928     3391402005  ...   $83,000.00
# 342938     3391452009  ...   $74,000.00
# 342946     3391472004  ...  $111,000.00
# 342951     3391492010  ...  $107,000.00
# 344784     3403402003  ...  $458,000.00
# 350109     3438122002  ...  $225,000.00
# 378899     3662512006  ...   $74,000.00
# 410929     3970852005  ...  $232,000.00
# 410933     3970882003  ...   $52,000.00
# ...

# %%
nr = df[df['NAICS']==0]
r = df[df['NAICS']!=0]
print(r)
# Out:
#         LoanNr_ChkDgt  ...      SBA_Appv
# 0          1000014003  ...   $48,000.00
# 1          1000024006  ...   $32,000.00
# 2          1000034009  ...  $215,250.00
# 5          1000084002  ...  $387,750.00
# 7          1000094005  ...   $36,000.00
# ...               ...  ...           ...
# 899156     9995473009  ...   $25,000.00
# 899157     9995493004  ...  $150,000.00
# 899159     9995573004  ...   $56,000.00
# 899160     9995603000  ...   $42,500.00
# 899161     9995613003  ...  $225,000.00
#
# [697216 rows x 27 columns]

# %%
dup = nr['Name'].duplicated()

nr[dup].sort_values(by='Name')
# Out:
#         LoanNr_ChkDgt  ...      SBA_Appv
# 815426     8739323006  ...   $68,000.00
# 532379     5191543002  ...   $68,000.00
# 450122     4366483006  ...   $63,000.00
# 405531     3913914006  ...    $7,500.00
# 858986     9233283004  ...  $187,500.00
# ...               ...  ...           ...
# 179433     2278324001  ...  $199,500.00
# 12933      1092144003  ...   $96,000.00
# 409076     3952053004  ...  $999,886.00
# 197401     2392194003  ...   $32,000.00
# 198019     2396634001  ...   $24,000.00
#
# [22768 rows x 27 columns]

# %%
common_values = set(r['Name']).intersection(set(nr['Name']))

common_values
# Out:
# {'MIDGET MARKET',
#  "MARVIN'S",
#  'INDY LUBE',
#  'SPARKS TUNE UP',
#  'PHOTOGRAPHICS',
#  'AMERICAN PRINTING, INC.',
#  'TRADE RITE MARKET',
#  'EL RINCONCITO',
#  'NOBLE HOUSE',
#  'PRECISION TECHNOLOGIES INC',
#  'THE LANTERN HOUSE',
#  'ALPINE INSULATION CO., INC.',
#  'WILDFLOWER INTERNATIONAL, LTD.',
#  'CLARK INDUSTRIES, INC.',
#  'HIGHLAND MEDICAL EQUIPMENT',
#  'JACK RAY & SONS OIL CO., INC.',
#  'SMOKEY POINT PLANT FARM, INC.',
#  'RONZIO PIZZA',
#  'DON SMITH VETERINARY SERVICES',
#  'CHINA DRAGON',
#  'BETTER TRADE MARKET',
#  'D & D SERVICES',
#  'SPEEDEE OIL CHANGE & TUNE UP',
#  'COLDWELL BANKER',
#  'BREE ENGINEERING, INC.',
#  'NAPA',
#  'ATEC, INC.',
#  'COLD BEER & CHEESEBURGERS',
#  'ALPINE POWER EQUIPMENT',
#  'LUCKY FOOD MART',
#  'J & G LANDSCAPING',
#  'RED APPLE RESTAURANT',
#  'FIVE STAR INDUSTRIES, INC.',
#  "ANDERSON'S GROCERY",
#  'J & N QUALITY FOODS',
#  'CONNECTION MOLD, INC.',
#  'DeeAnn Echols',
#  'NEPTUNE ENTERPRISES, INC.',
# ...
